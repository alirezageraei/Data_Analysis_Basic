# %% [markdown]
# ## Priject 3: Customers Churn
# ###### Predict the churn parameter of customers based on Kaggle churn dataset information.

# %% [markdown]
# ### Import required packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load dataset

# %%
url = "https://raw.githubusercontent.com/sharmaroshan/Churn-Modelling-Dataset/refs/heads/master/Churn_Modelling.csv"
df = pd.read_csv(url)
df.head(7)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# ...

# %% [markdown]
# ### Data Observation

# %%
print("Shape:", df.shape)
print("------------------------------------------------------------\n")
print(df.describe())
print("------------------------------------------------------------\n")
print(df.info())
print("------------------------------------------------------------\n")
print(df.isnull().sum())
print("------------------------------------------------------------\n")
print(df.nunique())
# Out:
# Shape: (10000, 14)
# ------------------------------------------------------------
#
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# ...

# %% [markdown]
# `df.groupby(["Gender"])["Exited"].agg(["count", "mean"])`
# `df.groupby(["Age"])["Exited"].agg(["count", "mean"])`
# `df.groupby(["Tenure"])["Exited"].agg(["count", "mean"])`
# `df.groupby(["NumOfProducts"])["Exited"].agg(["count", "mean"])`
# `df.groupby(["IsActiveMember"])["Exited"].agg(["count", "mean"])`
# ...

# %%
ct = pd.crosstab(df["IsActiveMember"], df["Exited"])
ct.plot(kind="bar", figsize=(8, 5))
plt.show()

# %%
ct = pd.crosstab(df["NumOfProducts"], df["Exited"])
ct.plot(kind="bar", figsize=(8, 5))
plt.show()

# %%
ct = pd.crosstab(df["Tenure"], df["Exited"])
ct.plot(kind="line", figsize=(8, 5))
plt.show()

# %%
ct = pd.crosstab(df["Gender"], df["Exited"])
ct.plot(kind="bar", figsize=(8, 5))
plt.show()

# %%
ct = pd.crosstab(df["Age"], df["Exited"])
ct.plot(kind="line", figsize=(8, 5))
plt.show()

# %%
ct = pd.crosstab(df["EstimatedSalary"], df["Exited"])
ct.plot(kind="bar", figsize=(8, 5))
plt.show()
